# %%
# Librerías 

# Ánalisis y manipulación de datos
import pandas as pd         
import numpy as np

# Interacción con sistemas de archivos
import os

# %% [markdown]
# ## Cargando datos a un dataframe

# %%
# Directorio donde se encuentran los archivos TSV
folder = '../Ficheros/limpios'
files = os.listdir(folder)
files

# Lista para guardar cada dataframe leído
dfs = []

# Recorre cada archivo del directorio que termine en .tsv o .txt
for file in files:    
    if file.endswith('.tsv') or file.endswith('.txt'):                                                          # Filtra solo los archivos con extensión .tsv, .txt        
        file_name = os.path.splitext(file)[0]                                                                   # Obtiene el nombre del archivo sin extensión
        df = pd.read_csv(os.path.join(folder, file), sep="\t", names=['source', 'target'], encoding="UTF-8")    # Lee el archivo. Arg(ruta) y une utilizando sep del SO
        df['file_name'] = file_name                                                                             # Agrega la columna con el nombre del archivo          
        dfs.append(df)                                                                                          # Agrega el dataframe a la lista de dataframes 
df_final = pd.concat(dfs, ignore_index=True)                                                                    # Concatena todos los dataframes en uno solo

df_final
# Out:
#                                                      source  \
# 0         A country whose people are not even aware that...
# 1         ! - - - - - - Contest Announcement!! - - - - -...
# 2                     ! Much Easier to Control the Spread.!
# 3         ! The Administration can of course clamp Lockd...
# 4         !!! WE DO’NT YET KNOW, THE DEGREE IF EFFICATIO...
# ...                                                     ...
# 19511586  “…there is force in the classical philosophica...
# 19511587  “…these are outrageous charges,” or “…we are c...
# 19511588                              “…they let you do it.
# 19511589  “…truth about Trump…” Is there something the w...
# 19511590  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                                                      target  \
# 0         Un país cuyo pueblo ni siquiera es consciente ...
# 1                     ¡! - - - - - ¡Concurso!! ¡- - - - - !
# 2          ¡! Es mucho más fácil controlar la propagación.!
# 3         ¡! La Administración puede, por supuesto, suje...
# 4          ¡¡¡!!! NO SABEMOS TODAVÍA, EL GRADO DE EFICACIA.
# ...                                                     ...
# 19511586  '...tiene fuerza el axioma filosófico clásico ...
# 19511587  '...son acusaciones escandalosas", o "...estam...
# 19511588                           '...le permiten hacerlo.
# 19511589  '...la verdad sobre Trump..." Hay algo que el ...
# 19511590  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                    file_name
# 0               q_en_en-es_d
# 1               q_en_en-es_d
# 2               q_en_en-es_d
# 3               q_en_en-es_d
# 4               q_en_en-es_d
# ...                      ...
# 19511586  quora_en_3_en-es_d
# 19511587  quora_en_3_en-es_d
# 19511588  quora_en_3_en-es_d
# 19511589  quora_en_3_en-es_d
# 19511590  quora_en_3_en-es_d
#
# [19511591 rows x 3 columns]

# %%
# Guarda el dataframe en un archivo CSV para utilizarlo en la visualización de datos en Streamlit
df_final.to_csv('../Ficheros/csv/df_original.csv', sep='\t')

# %% [markdown]
# Observaciones: se agrega una nueva columna al set de datos (file_name) para luego tener identificado la fuente de donde se obtuvo cada frase.

# %%
df_final.shape
# Out:
# (19511591, 3)

# %% [markdown]
# ## Descripción general del dataframe
# El dataset contiene 3 variables: <br>
# - source: frases en inglés <br>
# - target: traducción al español <br>
# - file_name: nombre de la fuente donde se obtuvieron los datos <br>
#
# Cuenta con 19 511 591 observaciones.
#
# El tipo de dato de cada una de las 3 columnas es object, lo que significa que son variables categóricas.

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19511591 entries, 0 to 19511590
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   source     object
#  1   target     object
#  2   file_name  object
# dtypes: object(3)
# memory usage: 446.6+ MB

# %% [markdown]
# ## Descripción estadística de los datos.
#
#
# ### Las estadísticas que aparecen en la tabla son las siguientes:
#
# 1. **count:** número de valores no nulos en cada columna.
# 2. **unique:** número de valores únicos en cada columna.
# 3. **top:** valor más común en cada columna.
# 4. **freq:** frecuencia del valor más común en cada columna.

# %%
df_final.describe()
# Out:
#                                                    source    target  \
# count                                            19511591  19511591
# unique                                           16850800  16981971
# top     Most home exercise equipment and most holiday ...    [...].
# freq                                                 2197     46055
#
#                  file_name
# count             19511591
# unique                  31
# top     en_ecomm_rev_en-es
# freq               4936607

# %% [markdown]
# ### Cantidad de valores únicos en columna de un DataFrame. En este caso la columna "source"

# %%
df_final['source'].nunique()
# Out:
# 16850800

# %% [markdown]
# Observaciones: Se puede identificar que existen frases repetidas en el source.

# %% [markdown]
# ### Eliminar filas duplicadas en el "source"

# %%
df_final.drop_duplicates(subset=['source'], inplace=True)         # subset: columnas a considerar para la eliminación de duplicados

# %%
df_final
# Out:
#                                                      source  \
# 0         A country whose people are not even aware that...
# 1         ! - - - - - - Contest Announcement!! - - - - -...
# 2                     ! Much Easier to Control the Spread.!
# 3         ! The Administration can of course clamp Lockd...
# 4         !!! WE DO’NT YET KNOW, THE DEGREE IF EFFICATIO...
# ...                                                     ...
# 19511586  “…there is force in the classical philosophica...
# 19511587  “…these are outrageous charges,” or “…we are c...
# 19511588                              “…they let you do it.
# 19511589  “…truth about Trump…” Is there something the w...
# 19511590  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                                                      target  \
# 0         Un país cuyo pueblo ni siquiera es consciente ...
# 1                     ¡! - - - - - ¡Concurso!! ¡- - - - - !
# 2          ¡! Es mucho más fácil controlar la propagación.!
# 3         ¡! La Administración puede, por supuesto, suje...
# 4          ¡¡¡!!! NO SABEMOS TODAVÍA, EL GRADO DE EFICACIA.
# ...                                                     ...
# 19511586  '...tiene fuerza el axioma filosófico clásico ...
# 19511587  '...son acusaciones escandalosas", o "...estam...
# 19511588                           '...le permiten hacerlo.
# 19511589  '...la verdad sobre Trump..." Hay algo que el ...
# 19511590  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                    file_name
# 0               q_en_en-es_d
# 1               q_en_en-es_d
# 2               q_en_en-es_d
# 3               q_en_en-es_d
# 4               q_en_en-es_d
# ...                      ...
# 19511586  quora_en_3_en-es_d
# 19511587  quora_en_3_en-es_d
# 19511588  quora_en_3_en-es_d
# 19511589  quora_en_3_en-es_d
# 19511590  quora_en_3_en-es_d
#
# [16850800 rows x 3 columns]

# %% [markdown]
# ### Reiniciar índices

# %%
df = df_final.reset_index(drop=True)
df
# Out:
#                                                      source  \
# 0         A country whose people are not even aware that...
# 1         ! - - - - - - Contest Announcement!! - - - - -...
# 2                     ! Much Easier to Control the Spread.!
# 3         ! The Administration can of course clamp Lockd...
# 4         !!! WE DO’NT YET KNOW, THE DEGREE IF EFFICATIO...
# ...                                                     ...
# 16850795  “…there is force in the classical philosophica...
# 16850796  “…these are outrageous charges,” or “…we are c...
# 16850797                              “…they let you do it.
# 16850798  “…truth about Trump…” Is there something the w...
# 16850799  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                                                      target  \
# 0         Un país cuyo pueblo ni siquiera es consciente ...
# 1                     ¡! - - - - - ¡Concurso!! ¡- - - - - !
# 2          ¡! Es mucho más fácil controlar la propagación.!
# 3         ¡! La Administración puede, por supuesto, suje...
# 4          ¡¡¡!!! NO SABEMOS TODAVÍA, EL GRADO DE EFICACIA.
# ...                                                     ...
# 16850795  '...tiene fuerza el axioma filosófico clásico ...
# 16850796  '...son acusaciones escandalosas", o "...estam...
# 16850797                           '...le permiten hacerlo.
# 16850798  '...la verdad sobre Trump..." Hay algo que el ...
# 16850799  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                    file_name
# 0               q_en_en-es_d
# 1               q_en_en-es_d
# 2               q_en_en-es_d
# 3               q_en_en-es_d
# 4               q_en_en-es_d
# ...                      ...
# 16850795  quora_en_3_en-es_d
# 16850796  quora_en_3_en-es_d
# 16850797  quora_en_3_en-es_d
# 16850798  quora_en_3_en-es_d
# 16850799  quora_en_3_en-es_d
#
# [16850800 rows x 3 columns]

# %% [markdown]
# ## Agregar nuevas variables

# %% [markdown]
# #### *Conteo de palabras*

# %%
# Contar palabras de una en cada fila del dataframe. Columna "source"
quantity_words_source = df['source'].apply(lambda frase: len(str(frase).split()))

# %%
quantity_words_source
# Out:
# 0           29
# 1           16
# 2            7
# 3           12
# 4           10
#             ..
# 16850795    25
# 16850796    10
# 16850797     5
# 16850798    28
# 16850799     8
# Name: source, Length: 16850800, dtype: int64

# %%
# Contar palabras de una frase en cada fila del dataframe. Columna "target"
quantity_words_target = df['target'].apply(lambda frase: len(str(frase).split()))

# %%
# Agregar nuevas columnas al dataframe original: "quantity_words_source" y "quantity_words_target"
df['quantity_words_source']= quantity_words_source
df['quantity_words_target']= quantity_words_target

# %%
df
# Out:
#                                                      source  \
# 0         A country whose people are not even aware that...
# 1         ! - - - - - - Contest Announcement!! - - - - -...
# 2                     ! Much Easier to Control the Spread.!
# 3         ! The Administration can of course clamp Lockd...
# 4         !!! WE DO’NT YET KNOW, THE DEGREE IF EFFICATIO...
# ...                                                     ...
# 16850795  “…there is force in the classical philosophica...
# 16850796  “…these are outrageous charges,” or “…we are c...
# 16850797                              “…they let you do it.
# 16850798  “…truth about Trump…” Is there something the w...
# 16850799  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                                                      target  \
# 0         Un país cuyo pueblo ni siquiera es consciente ...
# 1                     ¡! - - - - - ¡Concurso!! ¡- - - - - !
# 2          ¡! Es mucho más fácil controlar la propagación.!
# 3         ¡! La Administración puede, por supuesto, suje...
# 4          ¡¡¡!!! NO SABEMOS TODAVÍA, EL GRADO DE EFICACIA.
# ...                                                     ...
# 16850795  '...tiene fuerza el axioma filosófico clásico ...
# 16850796  '...son acusaciones escandalosas", o "...estam...
# 16850797                           '...le permiten hacerlo.
# 16850798  '...la verdad sobre Trump..." Hay algo que el ...
# 16850799  īśvaraḥ paramaḥ kṛṣṇaḥ sac-cid-ānanda-vigrahaḥ...
#
#                    file_name  quantity_words_source  quantity_words_target
# 0               q_en_en-es_d                     29                     25
# 1               q_en_en-es_d                     16                     13
# 2               q_en_en-es_d                      7                      8
# 3               q_en_en-es_d                     12                     13
# 4               q_en_en-es_d                     10                      8
# ...                      ...                    ...                    ...
# 16850795  quora_en_3_en-es_d                     25                     24
# 16850796  quora_en_3_en-es_d                     10                     10
# 16850797  quora_en_3_en-es_d                      5                      3
# 16850798  quora_en_3_en-es_d                     28                     26
# 16850799  quora_en_3_en-es_d                      8                      8
#
# [16850800 rows x 5 columns]

# %% [markdown]
# [Siguiente: NLP](3_proc_texto.ipynb)
